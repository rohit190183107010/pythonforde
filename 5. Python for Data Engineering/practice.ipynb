# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'date':['3/10/2000', '3/11/2000','3/12/2000'],'value':[2,3,4]})

# %%
df
# Out:
#         date  value
# 0  3/10/2000      2
# 1  3/11/2000      3
# 2  3/12/2000      4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3 non-null      object
#  1   value   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3 non-null      datetime64[ns]
#  1   value   3 non-null      int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 176.0 bytes

# %%
df
# Out:
#         date  value
# 0 2000-03-10      2
# 1 2000-03-11      3
# 2 2000-03-12      4

# %%
df = pd.DataFrame({'date':['3/10/2000','3/11/2000','3/12/2000'],
                   'value':[2,3,4]})
df['date'] = pd.to_datetime(df['date'], dayfirst=True)

# %%
df
# Out:
#         date  value
# 0 2000-10-03      2
# 1 2000-11-03      3
# 2 2000-12-03      4

# %%
df = pd.DataFrame({'date': ['2016-6-10 20:30:0', 
                            '2016-7-1 19:45:30', 
                            '2013-10-12 4:5:1'],
                   'value': [2, 3, 4]})
df['date'] = pd.to_datetime(df['date'], format="%Y-%d-%m %H:%M:%S")

# %%
df
# Out:
#                  date  value
# 0 2016-10-06 20:30:00      2
# 1 2016-01-07 19:45:30      3
# 2 2013-12-10 04:05:01      4

# %%
df = pd.DataFrame({'date':['3/11/2000','3/12/2000','3/13/2000']*1000})
df.head()
# Out:
#         date
# 0  3/11/2000
# 1  3/12/2000
# 2  3/13/2000
# 3  3/11/2000
# 4  3/12/2000

# %%
df = pd.DataFrame({'date':['3/10/2000', 'a/11/2000','3/12/2000'],'value':[2,3,4]})

# %%
df
# Out:
#         date  value
# 0  3/10/2000      2
# 1  a/11/2000      3
# 2  3/12/2000      4

# %%
df['date'] = pd.to_datetime(df['date'])
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslibs\parsing.pyx:320, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#
# ParserError: Unknown string format: a/11/2000
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "a/11/2000" at position 1
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 df['date'] = pd.to_datetime(df['date'])
#
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslibs\parsing.pyx:320, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     640 res, skipped_tokens = self._parse(timestr, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#     646     raise ParserError("String does not contain a date: %s", timestr)
#
# ParserError: Unknown string format: a/11/2000 present at position 1

# %%
df['date'] = pd.to_datetime(df['date'],errors='ignore')
df
# Out:
#         date  value
# 0  3/10/2000      2
# 1  a/11/2000      3
# 2  3/12/2000      4

# %%
df['date'] = pd.to_datetime(df['date'],errors='coerce')
df
# Out:
#         date  value
# 0 2000-03-10      2
# 1        NaT      3
# 2 2000-03-12      4

# %%
df = pd.DataFrame({'year':[2015,2016],'month':[2,3],'day':[4,5]})

# %%
df
# Out:
#    year  month  day
# 0  2015      2    4
# 1  2016      3    5

# %%
df['date'] = pd.to_datetime(df)
df
# Out:
#    year  month  day       date
# 0  2015      2    4 2015-02-04
# 1  2016      3    5 2016-03-05

# %%
df = pd.DataFrame({'name':['Tom','Andy','Lucas'],'DoB':['08-05-1997','04-28-1996','12-16-1995']})

# %%
df
# Out:
#     name         DoB
# 0    Tom  08-05-1997
# 1   Andy  04-28-1996
# 2  Lucas  12-16-1995

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   DoB     3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes

# %%
df['DoB'] = pd.to_datetime(df['DoB'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   DoB     3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 176.0+ bytes

# %%
df['Year']=df['DoB'].dt.year
df['month']=df['DoB'].dt.month
df['day']=df['DoB'].dt.day
df
# Out:
#     name        DoB  Year  month  day
# 0    Tom 1997-08-05  1997      8    5
# 1   Andy 1996-04-28  1996      4   28
# 2  Lucas 1995-12-16  1995     12   16

# %%
df['week_of_year'] = df['DoB'].dt.week
df['day_of_week'] = df['DoB'].dt.day
df['is_leap_year']=df['DoB'].dt.is_leap_year
df
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_17148\3636589550.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week_of_year'] = df['DoB'].dt.week
#     name        DoB  week_of_year  day_of_week  is_leap_year
# 0    Tom 1997-08-05            32            5         False
# 1   Andy 1996-04-28            17           28          True
# 2  Lucas 1995-12-16            50           16         False

# %%
df['DoB'].dt.weekday
# Out:
# 0    1
# 1    6
# 2    5
# Name: DoB, dtype: int64

# %%
dw_mapping={
    0:'Monday',
    1:'Tuesday',
    2:'Wednesday',
    3:'Thursday',
    4:'Friday',
    5:'Saturday',
    6:'Sunday'
}

df['day_of_week_name']=df['DoB'].dt.weekday.map(dw_mapping)
df
# Out:
#     name        DoB  week_of_year  day_of_week  is_leap_year day_of_week_name
# 0    Tom 1997-08-05            32            5         False          Tuesday
# 1   Andy 1996-04-28            17           28          True           Sunday
# 2  Lucas 1995-12-16            50           16         False         Saturday

# %%
pd.to_datetime('today').year - df['DoB'].dt.year
# Out:
# 0    26
# 1    27
# 2    28
# Name: DoB, dtype: int64

# %%
today = pd.to_datetime('today')
df['age'] = today.year - df['DoB'].dt.year
df
# Out:
#     name        DoB  week_of_year  day_of_week  is_leap_year day_of_week_name  \
# 0    Tom 1997-08-05            32            5         False          Tuesday
# 1   Andy 1996-04-28            17           28          True           Sunday
# 2  Lucas 1995-12-16            50           16         False         Saturday
#
#    age
# 0   26
# 1   27
# 2   28

# %%
today = pd.to_datetime('today')
diff_y = today.year - df['DoB'].dt.year

b_md = df['DoB'].apply(lambda x:(x.month,x.day))
no_birthday=b_md>(today.month,today.day)

df['age']=diff_y-no_birthday
df
# Out:
#     name        DoB  week_of_year  day_of_week  is_leap_year day_of_week_name  \
# 0    Tom 1997-08-05            32            5         False          Tuesday
# 1   Andy 1996-04-28            17           28          True           Sunday
# 2  Lucas 1995-12-16            50           16         False         Saturday
#
#    age
# 0   25
# 1   26
# 2   27

# %%
no_birthday
# Out:
# 0    True
# 1    True
# 2    True
# Name: DoB, dtype: bool

# %%
df = pd.read_csv('data/city_sales.csv',
                parse_dates=['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376433 entries, 0 to 376432
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    376433 non-null  datetime64[ns]
#  1   num     376433 non-null  int64
#  2   city    376433 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 8.6+ MB

# %%
df = df.set_index(['date'])
df
# Out:
#                      num    city
# date
# 2015-01-01 09:00:00    4  London
# 2015-01-01 09:01:00    4  London
# 2015-01-01 09:02:00    3  London
# 2015-01-01 09:03:00    3  London
# 2015-01-01 09:04:00    3  London
# ...                  ...     ...
# 2018-06-06 09:54:00    3  London
# 2018-06-06 09:55:00    3  London
# 2018-06-06 09:56:00    3  London
# 2018-06-06 09:57:00    3  London
# 2018-06-06 09:58:00    1  London
#
# [376433 rows x 2 columns]

# %%
df.loc['2018']
# Out:
#                      num    city
# date
# 2018-01-01 09:00:00    2  London
# 2018-01-01 09:01:00    1  London
# 2018-01-01 09:02:00    3  London
# 2018-01-01 09:03:00    3  London
# 2018-01-01 09:04:00    3  London
# ...                  ...     ...
# 2018-06-06 09:54:00    3  London
# 2018-06-06 09:55:00    3  London
# 2018-06-06 09:56:00    3  London
# 2018-06-06 09:57:00    3  London
# 2018-06-06 09:58:00    1  London
#
# [47211 rows x 2 columns]

# %%
df.loc['2018','num'].sum()
# Out:
# 132127

# %%
df['2018'].groupby('city').sum()
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_17148\1368259670.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2018'].groupby('city').sum()
#            num
# city
# London  132127

# %%
df.loc['2018-5']
# Out:
#                      num    city
# date
# 2018-05-01 09:00:00    1  London
# 2018-05-01 09:01:00    4  London
# 2018-05-01 09:02:00    3  London
# 2018-05-01 09:03:00    2  London
# 2018-05-01 09:04:00    3  London
# ...                  ...     ...
# 2018-05-31 15:56:00    3  London
# 2018-05-31 15:57:00    3  London
# 2018-05-31 15:58:00    4  London
# 2018-05-31 15:59:00    2  London
# 2018-05-31 16:00:00    3  London
#
# [9683 rows x 2 columns]

# %%
df.loc['2018-5-1']
# Out:
#                      num    city
# date
# 2018-05-01 09:00:00    1  London
# 2018-05-01 09:01:00    4  London
# 2018-05-01 09:02:00    3  London
# 2018-05-01 09:03:00    2  London
# 2018-05-01 09:04:00    3  London
# ...                  ...     ...
# 2018-05-01 15:56:00    2  London
# 2018-05-01 15:57:00    4  London
# 2018-05-01 15:58:00    1  London
# 2018-05-01 15:59:00    4  London
# 2018-05-01 16:00:00    1  London
#
# [421 rows x 2 columns]

# %%
cond = df.index.month==3
cond
# Out:
# array([False, False, False, ..., False, False, False])

# %%
df[cond]
# Out:
#                      num    city
# date
# 2015-03-02 09:00:00    1  London
# 2015-03-02 09:01:00    3  London
# 2015-03-02 09:02:00    2  London
# 2015-03-02 09:03:00    3  London
# 2015-03-02 09:04:00    1  London
# ...                  ...     ...
# 2018-03-30 15:56:00    4  London
# 2018-03-30 15:57:00    2  London
# 2018-03-30 15:58:00    3  London
# 2018-03-30 15:59:00    3  London
# 2018-03-30 16:00:00    3  London
#
# [37890 rows x 2 columns]

# %%
cond=df.index.month==2
df[cond]
# Out:
#                      num    city
# date
# 2015-02-02 09:00:00    4  London
# 2015-02-02 09:01:00    3  London
# 2015-02-02 09:02:00    3  London
# 2015-02-02 09:03:00    2  London
# 2015-02-02 09:04:00    1  London
# ...                  ...     ...
# 2018-02-28 15:56:00    3  London
# 2018-02-28 15:57:00    3  London
# 2018-02-28 15:58:00    3  London
# 2018-02-28 15:59:00    2  London
# 2018-02-28 16:00:00    3  London
#
# [34101 rows x 2 columns]

# %%
df.loc['2016':'2018']
# Out:
#                      num    city
# date
# 2016-01-01 09:00:00    4  London
# 2016-01-01 09:01:00    3  London
# 2016-01-01 09:02:00    4  London
# 2016-01-01 09:03:00    4  London
# 2016-01-01 09:04:00    2  London
# ...                  ...     ...
# 2018-06-06 09:54:00    3  London
# 2018-06-06 09:55:00    3  London
# 2018-06-06 09:56:00    3  London
# 2018-06-06 09:57:00    3  London
# 2018-06-06 09:58:00    1  London
#
# [266552 rows x 2 columns]

# %%
df.loc['2018-5-2 10':'2018-5-2 11']
# Out:
#                      num    city
# date
# 2018-05-02 10:00:00    2  London
# 2018-05-02 10:01:00    3  London
# 2018-05-02 10:02:00    4  London
# 2018-05-02 10:03:00    4  London
# 2018-05-02 10:04:00    4  London
# ...                  ...     ...
# 2018-05-02 11:55:00    4  London
# 2018-05-02 11:56:00    3  London
# 2018-05-02 11:57:00    4  London
# 2018-05-02 11:58:00    3  London
# 2018-05-02 11:59:00    4  London
#
# [120 rows x 2 columns]

# %%
df.loc['2018-5-2 10:30':'2018-5-2 10:45']
# Out:
#                      num    city
# date
# 2018-05-02 10:30:00    3  London
# 2018-05-02 10:31:00    3  London
# 2018-05-02 10:32:00    1  London
# 2018-05-02 10:33:00    3  London
# 2018-05-02 10:34:00    3  London
# 2018-05-02 10:35:00    3  London
# 2018-05-02 10:36:00    3  London
# 2018-05-02 10:37:00    2  London
# 2018-05-02 10:38:00    3  London
# 2018-05-02 10:39:00    3  London
# 2018-05-02 10:40:00    2  London
# 2018-05-02 10:41:00    4  London
# 2018-05-02 10:42:00    3  London
# 2018-05-02 10:43:00    3  London
# 2018-05-02 10:44:00    3  London
# 2018-05-02 10:45:00    4  London

# %%
df.between_time('10:30','10:45')
# Out:
#                      num    city
# date
# 2015-01-01 10:30:00    4  London
# 2015-01-01 10:31:00    3  London
# 2015-01-01 10:32:00    3  London
# 2015-01-01 10:33:00    3  London
# 2015-01-01 10:34:00    4  London
# ...                  ...     ...
# 2018-06-05 10:41:00    3  London
# 2018-06-05 10:42:00    3  London
# 2018-06-05 10:43:00    1  London
# 2018-06-05 10:44:00    2  London
# 2018-06-05 10:45:00    3  London
#
# [14304 rows x 2 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rolling_sum'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 df['rolling_sum_backfilled'] = df['rolling_sum'].fillna(method='backfill')
#       2 df.head()
#
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File c:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'rolling_sum'
